# %% [markdown]
# # frame

# %%
import numpy as numpy
import pandas as pd

# %%
# BigEnough DATA
X_train, y_train, X_test, y_test

# %%
# Models and Hyper Parameters
model = DFNet()

device
model.to(device)

89 aspoptimizer

criterion


# %%
# sample selection and Batch training function

# %%
# coutinual learning training
reinit

scaler

################################
print(f"before train")
for task in range(config.nb_task):

    config.n_class = config.init_classes + task * config.n_inc
    config.task = task

    X_train_t, Y_train_t, train_loader, X_test_t, Y_test_t, test_loader, scaler = data_task(config, X_train, Y_train, X_test, Y_test, scaler)
    config.nb_batch = int(len(X_train_t)/config.batchsize)

    logits_collect = col_arr(config, X_train_t)

    for epoch in range(config.epochs):
        for n, (inputs, labels) in enumerate(train_loader):
           
           input
           label

           # 학습


           # past
           deepcopy

# %% [markdown]
# # test

# %%
import import_ipynb
import pandas as pd
import numpy as np

import tensorflow as tf
from tensorflow.keras.optimizers.legacy import Adamax, Adam

from copy import deepcopy

# %%
import Model 
from Model import *

# %%
import utils
from utils import *

# %%
import train 
from train import *

# %%
data = pd.read_pickle('mon_data.pkl')
print(data.shape)
MAX_LABEL = 50
# Out:
# (19000, 2)

# %%
MAX_LABEL = 50
model = DFNet.build(input_shape=(10000, 1), classes=MAX_LABEL)
# 옵티마이저 설정 
OPTIMIZER = Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
train_loop(model, OPTIMIZER, MAX_LABEL, data, test_size=0.2, first_task = 39, inc_task = 5, first_epochs = 50, inc_epochs = 10, lamb=0.5, num_sample=100)
# Out:
# Epoch 1/50
# 200/200 - 13s - loss: 3.7137 - accuracy: 0.0831 - 13s/epoch - 67ms/step
# Epoch 2/50
# 200/200 - 11s - loss: 3.1368 - accuracy: 0.1669 - 11s/epoch - 56ms/step
# Epoch 3/50
# 200/200 - 11s - loss: 2.8007 - accuracy: 0.2291 - 11s/epoch - 56ms/step
# Epoch 4/50
# 200/200 - 11s - loss: 2.5382 - accuracy: 0.2909 - 11s/epoch - 57ms/step
# Epoch 5/50
# 200/200 - 11s - loss: 2.2918 - accuracy: 0.3552 - 11s/epoch - 56ms/step
# Epoch 6/50
# 200/200 - 11s - loss: 2.0940 - accuracy: 0.4153 - 11s/epoch - 56ms/step
# Epoch 7/50
# 200/200 - 11s - loss: 1.9317 - accuracy: 0.4514 - 11s/epoch - 57ms/step
# Epoch 8/50
# 200/200 - 11s - loss: 1.7778 - accuracy: 0.5045 - 11s/epoch - 57ms/step
# Epoch 9/50
# 200/200 - 11s - loss: 1.6149 - accuracy: 0.5403 - 11s/epoch - 57ms/step
# Epoch 10/50
# 200/200 - 11s - loss: 1.5057 - accuracy: 0.5788 - 11s/epoch - 57ms/step
# Epoch 11/50
# 200/200 - 12s - loss: 1.3707 - accuracy: 0.6134 - 12s/epoch - 58ms/step
# Epoch 12/50
# ...

# %%
MAX_LABEL = 50
model = DFNet.build(input_shape=(10000, 1), classes=MAX_LABEL)
# 옵티마이저 설정 
OPTIMIZER = Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
train_loop(model, OPTIMIZER, MAX_LABEL, data, test_size=0.2, first_task = 39, inc_task = 5, first_epochs = 50, inc_epochs = 10, lamb=10, num_sample=100)
# Out:
# Epoch 1/50
# 200/200 - 13s - loss: 3.7164 - accuracy: 0.0831 - 13s/epoch - 67ms/step
# Epoch 2/50
# 200/200 - 12s - loss: 3.1357 - accuracy: 0.1645 - 12s/epoch - 59ms/step
# Epoch 3/50
# 200/200 - 11s - loss: 2.8233 - accuracy: 0.2236 - 11s/epoch - 55ms/step
# Epoch 4/50
# 200/200 - 11s - loss: 2.6149 - accuracy: 0.2703 - 11s/epoch - 55ms/step
# Epoch 5/50
# 200/200 - 11s - loss: 2.3710 - accuracy: 0.3334 - 11s/epoch - 56ms/step
# Epoch 6/50
# 200/200 - 11s - loss: 2.1916 - accuracy: 0.3834 - 11s/epoch - 56ms/step
# Epoch 7/50
# 200/200 - 11s - loss: 2.0286 - accuracy: 0.4209 - 11s/epoch - 56ms/step
# Epoch 8/50
# 200/200 - 11s - loss: 1.8650 - accuracy: 0.4786 - 11s/epoch - 56ms/step
# Epoch 9/50
# 200/200 - 11s - loss: 1.7052 - accuracy: 0.5247 - 11s/epoch - 56ms/step
# Epoch 10/50
# 200/200 - 11s - loss: 1.6293 - accuracy: 0.5481 - 11s/epoch - 56ms/step
# Epoch 11/50
# 200/200 - 11s - loss: 1.4924 - accuracy: 0.5813 - 11s/epoch - 57ms/step
# Epoch 12/50
# ...

# %%
MAX_LABEL = 50
model = DFNet.build(input_shape=(10000, 1), classes=MAX_LABEL)
# 옵티마이저 설정 
OPTIMIZER = Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
train_loop(model, OPTIMIZER, MAX_LABEL, data, test_size=0.2, first_task = 39, inc_task = 5, first_epochs = 50, inc_epochs = 10, lamb=100, num_sample=100)
# Out:
# Epoch 1/50
# 200/200 - 13s - loss: 3.7196 - accuracy: 0.0897 - 13s/epoch - 66ms/step
# Epoch 2/50
# 200/200 - 11s - loss: 3.0749 - accuracy: 0.1836 - 11s/epoch - 56ms/step
# Epoch 3/50
# 200/200 - 11s - loss: 2.8049 - accuracy: 0.2359 - 11s/epoch - 56ms/step
# Epoch 4/50
# 200/200 - 11s - loss: 2.5398 - accuracy: 0.2873 - 11s/epoch - 56ms/step
# Epoch 5/50
# 200/200 - 11s - loss: 2.3091 - accuracy: 0.3430 - 11s/epoch - 56ms/step
# Epoch 6/50
# 200/200 - 11s - loss: 2.1096 - accuracy: 0.4025 - 11s/epoch - 56ms/step
# Epoch 7/50
# 200/200 - 11s - loss: 1.9415 - accuracy: 0.4492 - 11s/epoch - 56ms/step
# Epoch 8/50
# 200/200 - 12s - loss: 1.7979 - accuracy: 0.4939 - 12s/epoch - 58ms/step
# Epoch 9/50
# 200/200 - 12s - loss: 1.6578 - accuracy: 0.5347 - 12s/epoch - 58ms/step
# Epoch 10/50
# 200/200 - 11s - loss: 1.5607 - accuracy: 0.5478 - 11s/epoch - 57ms/step
# Epoch 11/50
# 200/200 - 11s - loss: 1.4091 - accuracy: 0.5981 - 11s/epoch - 56ms/step
# Epoch 12/50
# ...

# %% [markdown]
# # outputs

# %%
MAX_LABEL = 94
model = DFNet.build(input_shape=(10000, 1), classes=MAX_LABEL)
# 옵티마이저 설정 
OPTIMIZER = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
train_loop(model, OPTIMIZER, MAX_LABEL, data, test_size=0.2, first_task = 69, inc_task = 5, first_epochs = 50, inc_epochs = 10, lamb=0, num_sample=100)
# Out:
# Epoch 1/50
# 350/350 - 26s - loss: 4.0189 - accuracy: 0.0830 - 26s/epoch - 75ms/step
# Epoch 2/50
# 350/350 - 21s - loss: 3.2698 - accuracy: 0.1813 - 21s/epoch - 59ms/step
# Epoch 3/50
# 350/350 - 20s - loss: 2.8495 - accuracy: 0.2669 - 20s/epoch - 58ms/step
# Epoch 4/50
# 350/350 - 20s - loss: 2.5344 - accuracy: 0.3355 - 20s/epoch - 58ms/step
# Epoch 5/50
# 350/350 - 20s - loss: 2.3008 - accuracy: 0.4045 - 20s/epoch - 58ms/step
# Epoch 6/50
# 350/350 - 20s - loss: 2.1052 - accuracy: 0.4435 - 20s/epoch - 58ms/step
# Epoch 7/50
# 350/350 - 21s - loss: 1.9303 - accuracy: 0.4960 - 21s/epoch - 59ms/step
# Epoch 8/50
# 350/350 - 21s - loss: 1.7765 - accuracy: 0.5371 - 21s/epoch - 60ms/step
# Epoch 9/50
# 350/350 - 21s - loss: 1.6454 - accuracy: 0.5732 - 21s/epoch - 59ms/step
# Epoch 10/50
# 350/350 - 21s - loss: 1.5394 - accuracy: 0.5900 - 21s/epoch - 59ms/step
# Epoch 11/50
# 350/350 - 20s - loss: 1.4305 - accuracy: 0.6208 - 20s/epoch - 58ms/step
# Epoch 12/50
# ...

# %%
MAX_LABEL = 94
model = DFNet.build(input_shape=(10000, 1), classes=MAX_LABEL)
# 옵티마이저 설정 
OPTIMIZER = Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
train_loop(model, OPTIMIZER, MAX_LABEL, data, test_size=0.2, first_task = 69, inc_task = 5, first_epochs = 70, inc_epochs = 10, lamb=10, num_sample=100)
# Out:
# Epoch 1/70
# 350/350 - 24s - loss: 4.2442 - accuracy: 0.0538 - 24s/epoch - 69ms/step
# Epoch 2/70
# 350/350 - 21s - loss: 3.6022 - accuracy: 0.1240 - 21s/epoch - 59ms/step
# Epoch 3/70
# 350/350 - 21s - loss: 3.2072 - accuracy: 0.1885 - 21s/epoch - 59ms/step
# Epoch 4/70
# 350/350 - 21s - loss: 2.8781 - accuracy: 0.2626 - 21s/epoch - 59ms/step
# Epoch 5/70
# 350/350 - 22s - loss: 2.5934 - accuracy: 0.3248 - 22s/epoch - 63ms/step
# Epoch 6/70
# 350/350 - 21s - loss: 2.3760 - accuracy: 0.3816 - 21s/epoch - 61ms/step
# Epoch 7/70
# 350/350 - 21s - loss: 2.1743 - accuracy: 0.4382 - 21s/epoch - 59ms/step
# Epoch 8/70
# 350/350 - 21s - loss: 1.9975 - accuracy: 0.4758 - 21s/epoch - 59ms/step
# Epoch 9/70
# 350/350 - 21s - loss: 1.8504 - accuracy: 0.5158 - 21s/epoch - 59ms/step
# Epoch 10/70
# 350/350 - 21s - loss: 1.7037 - accuracy: 0.5508 - 21s/epoch - 61ms/step
# Epoch 11/70
# 350/350 - 22s - loss: 1.5823 - accuracy: 0.5852 - 22s/epoch - 63ms/step
# Epoch 12/70
# ...

# %%
MAX_LABEL = 94
model = DFNet_Leaky.build(input_shape=(10000, 1), classes=MAX_LABEL)
# 옵티마이저 설정 
OPTIMIZER = Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
train_loop(model, OPTIMIZER, MAX_LABEL, data, test_size=0.2, first_task = 69, inc_task = 5, first_epochs = 70, inc_epochs = 10, lamb=100, num_sample=100)
# Out:
# Epoch 1/70
# 350/350 - 24s - loss: 4.1558 - accuracy: 0.0696 - 24s/epoch - 69ms/step
# Epoch 2/70
# 350/350 - 21s - loss: 3.4646 - accuracy: 0.1457 - 21s/epoch - 60ms/step
# Epoch 3/70
# 350/350 - 22s - loss: 3.0159 - accuracy: 0.2270 - 22s/epoch - 63ms/step
# Epoch 4/70
# 350/350 - 21s - loss: 2.6835 - accuracy: 0.3093 - 21s/epoch - 61ms/step
# Epoch 5/70
# 350/350 - 21s - loss: 2.4339 - accuracy: 0.3694 - 21s/epoch - 60ms/step
# Epoch 6/70
# 350/350 - 21s - loss: 2.2043 - accuracy: 0.4290 - 21s/epoch - 60ms/step
# Epoch 7/70
# 350/350 - 21s - loss: 2.0202 - accuracy: 0.4746 - 21s/epoch - 60ms/step
# Epoch 8/70
# 350/350 - 21s - loss: 1.8423 - accuracy: 0.5202 - 21s/epoch - 60ms/step
# Epoch 9/70
# 350/350 - 22s - loss: 1.6948 - accuracy: 0.5558 - 22s/epoch - 64ms/step
# Epoch 10/70
# 350/350 - 21s - loss: 1.5401 - accuracy: 0.6000 - 21s/epoch - 61ms/step
# Epoch 11/70
# 350/350 - 21s - loss: 1.4270 - accuracy: 0.6297 - 21s/epoch - 60ms/step
# Epoch 12/70
# ...

# %%
MAX_LABEL = 94
model = DFNet_Leaky.build(input_shape=(10000, 1), classes=MAX_LABEL)
# 옵티마이저 설정 
OPTIMIZER = Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
train_loop(model, OPTIMIZER, MAX_LABEL, data, test_size=0.2, first_task = 69, inc_task = 5, first_epochs = 70, inc_epochs = 30, lamb=10000, num_sample=100)
# Out:
# Epoch 1/70
# 350/350 - 25s - loss: 4.1330 - accuracy: 0.0682 - 25s/epoch - 71ms/step
# Epoch 2/70
# 350/350 - 22s - loss: 3.4256 - accuracy: 0.1520 - 22s/epoch - 62ms/step
# Epoch 3/70
# 350/350 - 22s - loss: 2.9566 - accuracy: 0.2476 - 22s/epoch - 62ms/step
# Epoch 4/70
# 350/350 - 21s - loss: 2.6373 - accuracy: 0.3231 - 21s/epoch - 61ms/step
# Epoch 5/70
# 350/350 - 22s - loss: 2.3890 - accuracy: 0.3823 - 22s/epoch - 61ms/step
# Epoch 6/70
# 350/350 - 22s - loss: 2.1915 - accuracy: 0.4379 - 22s/epoch - 64ms/step
# Epoch 7/70
# 350/350 - 21s - loss: 1.9972 - accuracy: 0.4814 - 21s/epoch - 61ms/step
# Epoch 8/70
# 350/350 - 21s - loss: 1.8620 - accuracy: 0.5169 - 21s/epoch - 60ms/step
# Epoch 9/70
# 350/350 - 21s - loss: 1.6995 - accuracy: 0.5582 - 21s/epoch - 60ms/step
# Epoch 10/70
# 350/350 - 21s - loss: 1.5723 - accuracy: 0.5954 - 21s/epoch - 60ms/step
# Epoch 11/70
# 350/350 - 22s - loss: 1.4512 - accuracy: 0.6187 - 22s/epoch - 62ms/step
# Epoch 12/70
# ...

# %%
MAX_LABEL = 94
model = DFNet_Leaky.build(input_shape=(10000, 1), classes=MAX_LABEL)
# 옵티마이저 설정 
OPTIMIZER = Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
train_loop(model, OPTIMIZER, MAX_LABEL, data, test_size=0.2, first_task = 69, inc_task = 5, first_epochs = 100, inc_epochs = 10, lamb=100, num_sample=100)
# Out:
# Epoch 1/100
# 350/350 - 24s - loss: 4.1553 - accuracy: 0.0666 - 24s/epoch - 68ms/step
# Epoch 2/100
# 350/350 - 21s - loss: 3.4275 - accuracy: 0.1565 - 21s/epoch - 60ms/step
# Epoch 3/100
# 350/350 - 22s - loss: 2.9525 - accuracy: 0.2506 - 22s/epoch - 62ms/step
# Epoch 4/100
# 350/350 - 22s - loss: 2.6335 - accuracy: 0.3259 - 22s/epoch - 62ms/step
# Epoch 5/100
# 350/350 - 21s - loss: 2.3777 - accuracy: 0.3840 - 21s/epoch - 60ms/step
# Epoch 6/100
# 350/350 - 21s - loss: 2.1480 - accuracy: 0.4380 - 21s/epoch - 60ms/step
# Epoch 7/100
# 350/350 - 21s - loss: 1.9856 - accuracy: 0.4832 - 21s/epoch - 60ms/step
# Epoch 8/100
# 350/350 - 21s - loss: 1.8225 - accuracy: 0.5238 - 21s/epoch - 61ms/step
# Epoch 9/100
# 350/350 - 23s - loss: 1.6420 - accuracy: 0.5694 - 23s/epoch - 64ms/step
# Epoch 10/100
# 350/350 - 21s - loss: 1.5142 - accuracy: 0.6049 - 21s/epoch - 61ms/step
# Epoch 11/100
# 350/350 - 21s - loss: 1.4150 - accuracy: 0.6352 - 21s/epoch - 60ms/step
# Epoch 12/100
# ...

# %%
MAX_LABEL = 94
model = DFNet_Leaky.build(input_shape=(10000, 1), classes=MAX_LABEL)
# 옵티마이저 설정 
OPTIMIZER = Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
train_loop(model, OPTIMIZER, MAX_LABEL, data, test_size=0.2, first_task = 69, inc_task = 5, first_epochs = 10, inc_epochs = 20, lamb=2, num_sample=100)
# Out:
# Epoch 1/10
# 350/350 - 24s - loss: 4.1831 - accuracy: 0.0648 - 24s/epoch - 69ms/step
# Epoch 2/10
# 350/350 - 21s - loss: 3.4846 - accuracy: 0.1454 - 21s/epoch - 60ms/step
# Epoch 3/10
# 350/350 - 21s - loss: 3.0498 - accuracy: 0.2279 - 21s/epoch - 60ms/step
# Epoch 4/10
# 350/350 - 22s - loss: 2.7288 - accuracy: 0.2954 - 22s/epoch - 63ms/step
# Epoch 5/10
# 350/350 - 22s - loss: 2.4394 - accuracy: 0.3715 - 22s/epoch - 62ms/step
# Epoch 6/10
# 350/350 - 21s - loss: 2.2476 - accuracy: 0.4140 - 21s/epoch - 60ms/step
# Epoch 7/10
# 350/350 - 21s - loss: 2.0345 - accuracy: 0.4721 - 21s/epoch - 60ms/step
# Epoch 8/10
# 350/350 - 21s - loss: 1.8870 - accuracy: 0.5046 - 21s/epoch - 60ms/step
# Epoch 9/10
# 350/350 - 21s - loss: 1.7520 - accuracy: 0.5468 - 21s/epoch - 60ms/step
# Epoch 10/10
# 350/350 - 22s - loss: 1.6093 - accuracy: 0.5812 - 22s/epoch - 64ms/step
# 88/88 [==============================] - 3s 23ms/step - loss: 1.2019 - accuracy: 0.7107
# Task_0 training accuracy: 0.7107
#
# ...

# %%
MAX_LABEL = 94
model = DFNet_Leaky.build(input_shape=(10000, 1), classes=MAX_LABEL)
# 옵티마이저 설정 
OPTIMIZER = Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
train_loop(model, OPTIMIZER, MAX_LABEL, data, test_size=0.2, first_task = 69, inc_task = 5, first_epochs = 100, inc_epochs = 30, lamb=10, num_sample=100)
# Out:
# Epoch 1/100
# 350/350 - 24s - loss: 4.1765 - accuracy: 0.0650 - 24s/epoch - 69ms/step
# Epoch 2/100
# 350/350 - 21s - loss: 3.4878 - accuracy: 0.1482 - 21s/epoch - 61ms/step
# Epoch 3/100
# 350/350 - 22s - loss: 3.0517 - accuracy: 0.2263 - 22s/epoch - 63ms/step
# Epoch 4/100
# 350/350 - 21s - loss: 2.7097 - accuracy: 0.3019 - 21s/epoch - 60ms/step
# Epoch 5/100
# 350/350 - 21s - loss: 2.4637 - accuracy: 0.3627 - 21s/epoch - 60ms/step
# Epoch 6/100
# 350/350 - 21s - loss: 2.2351 - accuracy: 0.4204 - 21s/epoch - 60ms/step
# Epoch 7/100
# 350/350 - 21s - loss: 2.0462 - accuracy: 0.4636 - 21s/epoch - 60ms/step
# Epoch 8/100
# 350/350 - 22s - loss: 1.8984 - accuracy: 0.5046 - 22s/epoch - 63ms/step
# Epoch 9/100
# 350/350 - 22s - loss: 1.7498 - accuracy: 0.5421 - 22s/epoch - 62ms/step
# Epoch 10/100
# 350/350 - 21s - loss: 1.5987 - accuracy: 0.5854 - 21s/epoch - 60ms/step
# Epoch 11/100
# 350/350 - 21s - loss: 1.4704 - accuracy: 0.6178 - 21s/epoch - 60ms/step
# Epoch 12/100
# ...

# %%
MAX_LABEL = 94
model = DFNet_Leaky.build(input_shape=(10000, 1), classes=MAX_LABEL)
# 옵티마이저 설정 
OPTIMIZER = Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
train_loop(model, OPTIMIZER, MAX_LABEL, data, test_size=0.2, first_task = 69, inc_task = 5, first_epochs = 100, inc_epochs = 30, lamb=0.1, num_sample=100)
# Out:
# Epoch 1/100
# 350/350 - 25s - loss: 4.1880 - accuracy: 0.0633 - 25s/epoch - 70ms/step
# Epoch 2/100
# 350/350 - 21s - loss: 3.4911 - accuracy: 0.1419 - 21s/epoch - 60ms/step
# Epoch 3/100
# 350/350 - 22s - loss: 3.0664 - accuracy: 0.2212 - 22s/epoch - 62ms/step
# Epoch 4/100
# 350/350 - 22s - loss: 2.7229 - accuracy: 0.2989 - 22s/epoch - 63ms/step
# Epoch 5/100
# 350/350 - 21s - loss: 2.4776 - accuracy: 0.3571 - 21s/epoch - 60ms/step
# Epoch 6/100
# 350/350 - 21s - loss: 2.2594 - accuracy: 0.4160 - 21s/epoch - 60ms/step
# Epoch 7/100
# 350/350 - 21s - loss: 2.0726 - accuracy: 0.4554 - 21s/epoch - 60ms/step
# Epoch 8/100
# 350/350 - 21s - loss: 1.8964 - accuracy: 0.5065 - 21s/epoch - 60ms/step
# Epoch 9/100
# 350/350 - 22s - loss: 1.7407 - accuracy: 0.5448 - 22s/epoch - 64ms/step
# Epoch 10/100
# 350/350 - 22s - loss: 1.5996 - accuracy: 0.5861 - 22s/epoch - 62ms/step
# Epoch 11/100
# 350/350 - 21s - loss: 1.4638 - accuracy: 0.6181 - 21s/epoch - 60ms/step
# Epoch 12/100
# ...

# %%
MAX_LABEL = 94
model = DFNet_Leaky.build(input_shape=(10000, 1), classes=MAX_LABEL)
# 옵티마이저 설정 
OPTIMIZER = Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
train_loop(model, OPTIMIZER, MAX_LABEL, data, test_size=0.2, first_task = 69, inc_task = 5, first_epochs = 100, inc_epochs = 5, lamb=0.1, num_sample=100)
# Out:
# Epoch 1/100
# 350/350 - 24s - loss: 4.1783 - accuracy: 0.0603 - 24s/epoch - 69ms/step
# Epoch 2/100
# 350/350 - 21s - loss: 3.5105 - accuracy: 0.1360 - 21s/epoch - 60ms/step
# Epoch 3/100
# 350/350 - 21s - loss: 3.0725 - accuracy: 0.2193 - 21s/epoch - 60ms/step
# Epoch 4/100
# 350/350 - 22s - loss: 2.7361 - accuracy: 0.2966 - 22s/epoch - 63ms/step
# Epoch 5/100
# 350/350 - 22s - loss: 2.4582 - accuracy: 0.3662 - 22s/epoch - 62ms/step
# Epoch 6/100
# 350/350 - 21s - loss: 2.2554 - accuracy: 0.4156 - 21s/epoch - 60ms/step
# Epoch 7/100
# 350/350 - 21s - loss: 2.0661 - accuracy: 0.4550 - 21s/epoch - 60ms/step
# Epoch 8/100
# 350/350 - 21s - loss: 1.9193 - accuracy: 0.5022 - 21s/epoch - 60ms/step
# Epoch 9/100
# 350/350 - 21s - loss: 1.7343 - accuracy: 0.5459 - 21s/epoch - 61ms/step
# Epoch 10/100
# 350/350 - 23s - loss: 1.6320 - accuracy: 0.5761 - 23s/epoch - 65ms/step
# Epoch 11/100
# 350/350 - 21s - loss: 1.4758 - accuracy: 0.6157 - 21s/epoch - 61ms/step
# Epoch 12/100
# ...

# %%
MAX_LABEL = 74
model = DFNet_Leaky.build(input_shape=(10000, 1), classes=MAX_LABEL)
# 옵티마이저 설정 
OPTIMIZER = Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
train_loop(model, OPTIMIZER, MAX_LABEL, data, test_size=0.2, first_task = 49, inc_task = 5, first_epochs = 100, inc_epochs = 5, lamb=0.1, num_sample=100)
# Out:
# Epoch 1/100
# 250/250 - 19s - loss: 3.8461 - accuracy: 0.0835 - 19s/epoch - 75ms/step
# Epoch 2/100
# 250/250 - 16s - loss: 3.1779 - accuracy: 0.1813 - 16s/epoch - 62ms/step
# Epoch 3/100
# 250/250 - 15s - loss: 2.7557 - accuracy: 0.2650 - 15s/epoch - 60ms/step
# Epoch 4/100
# 250/250 - 15s - loss: 2.4735 - accuracy: 0.3252 - 15s/epoch - 60ms/step
# Epoch 5/100
# 250/250 - 15s - loss: 2.2246 - accuracy: 0.3956 - 15s/epoch - 60ms/step
# Epoch 6/100
# 250/250 - 15s - loss: 2.0258 - accuracy: 0.4426 - 15s/epoch - 60ms/step
# Epoch 7/100
# 250/250 - 15s - loss: 1.8237 - accuracy: 0.5055 - 15s/epoch - 60ms/step
# Epoch 8/100
# 250/250 - 16s - loss: 1.6832 - accuracy: 0.5462 - 16s/epoch - 62ms/step
# Epoch 9/100
# 250/250 - 16s - loss: 1.5303 - accuracy: 0.5894 - 16s/epoch - 64ms/step
# Epoch 10/100
# 250/250 - 15s - loss: 1.3821 - accuracy: 0.6246 - 15s/epoch - 61ms/step
# Epoch 11/100
# 250/250 - 15s - loss: 1.2897 - accuracy: 0.6522 - 15s/epoch - 60ms/step
# Epoch 12/100
# ...

# %%
MAX_LABEL = 54
model = DFNet_Leaky.build(input_shape=(10000, 1), classes=MAX_LABEL)
# 옵티마이저 설정 
OPTIMIZER = Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
train_loop(model, OPTIMIZER, MAX_LABEL, data, test_size=0.2, first_task = 29, inc_task = 5, first_epochs = 100, inc_epochs = 5, lamb=0.1, num_sample=100)
# Out:
# Epoch 1/100
# 150/150 - 12s - loss: 3.5477 - accuracy: 0.1010 - 12s/epoch - 82ms/step
# Epoch 2/100
# 150/150 - 9s - loss: 2.8974 - accuracy: 0.1950 - 9s/epoch - 61ms/step
# Epoch 3/100
# 150/150 - 9s - loss: 2.5638 - accuracy: 0.2717 - 9s/epoch - 60ms/step
# Epoch 4/100
# 150/150 - 9s - loss: 2.2750 - accuracy: 0.3425 - 9s/epoch - 60ms/step
# Epoch 5/100
# 150/150 - 9s - loss: 2.0798 - accuracy: 0.3965 - 9s/epoch - 60ms/step
# Epoch 6/100
# 150/150 - 9s - loss: 1.8714 - accuracy: 0.4525 - 9s/epoch - 60ms/step
# Epoch 7/100
# 150/150 - 9s - loss: 1.7235 - accuracy: 0.5013 - 9s/epoch - 62ms/step
# Epoch 8/100
# 150/150 - 9s - loss: 1.5128 - accuracy: 0.5654 - 9s/epoch - 63ms/step
# Epoch 9/100
# 150/150 - 9s - loss: 1.4077 - accuracy: 0.5965 - 9s/epoch - 61ms/step
# Epoch 10/100
# 150/150 - 9s - loss: 1.2661 - accuracy: 0.6244 - 9s/epoch - 61ms/step
# Epoch 11/100
# 150/150 - 9s - loss: 1.1551 - accuracy: 0.6654 - 9s/epoch - 60ms/step
# Epoch 12/100
# ...

# %%
MAX_LABEL = 74
model = DFNet_Leaky.build(input_shape=(10000, 1), classes=MAX_LABEL)
# 옵티마이저 설정 
OPTIMIZER = Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
train_loop(model, OPTIMIZER, MAX_LABEL, data, test_size=0.2, first_task = 49, inc_task = 5, first_epochs = 100, inc_epochs = 10, lamb=0.1, num_sample=100)
# Out:
# Epoch 1/100
# 250/250 - 18s - loss: 3.8434 - accuracy: 0.0861 - 18s/epoch - 72ms/step
# Epoch 2/100
# 250/250 - 16s - loss: 3.2001 - accuracy: 0.1750 - 16s/epoch - 63ms/step
# Epoch 3/100
# 250/250 - 16s - loss: 2.7959 - accuracy: 0.2528 - 16s/epoch - 64ms/step
# Epoch 4/100
# 250/250 - 15s - loss: 2.5016 - accuracy: 0.3207 - 15s/epoch - 60ms/step
# Epoch 5/100
# 250/250 - 15s - loss: 2.2558 - accuracy: 0.3866 - 15s/epoch - 60ms/step
# Epoch 6/100
# 250/250 - 15s - loss: 2.0777 - accuracy: 0.4335 - 15s/epoch - 60ms/step
# Epoch 7/100
# 250/250 - 15s - loss: 1.8910 - accuracy: 0.4829 - 15s/epoch - 60ms/step
# Epoch 8/100
# 250/250 - 15s - loss: 1.7333 - accuracy: 0.5210 - 15s/epoch - 60ms/step
# Epoch 9/100
# 250/250 - 15s - loss: 1.5741 - accuracy: 0.5670 - 15s/epoch - 60ms/step
# Epoch 10/100
# 250/250 - 16s - loss: 1.4440 - accuracy: 0.6065 - 16s/epoch - 63ms/step
# Epoch 11/100
# 250/250 - 16s - loss: 1.3321 - accuracy: 0.6399 - 16s/epoch - 63ms/step
# Epoch 12/100
# ...

# %%
MAX_LABEL = 54
model = DFNet_Leaky.build(input_shape=(10000, 1), classes=MAX_LABEL)
# 옵티마이저 설정 
OPTIMIZER = Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
train_loop(model, OPTIMIZER, MAX_LABEL, data, test_size=0.2, first_task = 29, inc_task = 5, first_epochs = 100, inc_epochs = 10, lamb=0.1, num_sample=100)
# Out:
# Epoch 1/100
# 150/150 - 12s - loss: 3.5192 - accuracy: 0.1096 - 12s/epoch - 80ms/step
# Epoch 2/100
# 150/150 - 9s - loss: 2.9459 - accuracy: 0.1921 - 9s/epoch - 61ms/step
# Epoch 3/100
# 150/150 - 9s - loss: 2.6023 - accuracy: 0.2706 - 9s/epoch - 60ms/step
# Epoch 4/100
# 150/150 - 9s - loss: 2.3518 - accuracy: 0.3221 - 9s/epoch - 60ms/step
# Epoch 5/100
# 150/150 - 9s - loss: 2.0764 - accuracy: 0.3877 - 9s/epoch - 60ms/step
# Epoch 6/100
# 150/150 - 9s - loss: 1.9094 - accuracy: 0.4458 - 9s/epoch - 62ms/step
# Epoch 7/100
# 150/150 - 10s - loss: 1.7304 - accuracy: 0.4881 - 10s/epoch - 63ms/step
# Epoch 8/100
# 150/150 - 10s - loss: 1.5439 - accuracy: 0.5481 - 10s/epoch - 64ms/step
# Epoch 9/100
# 150/150 - 9s - loss: 1.4302 - accuracy: 0.5754 - 9s/epoch - 62ms/step
# Epoch 10/100
# 150/150 - 9s - loss: 1.3027 - accuracy: 0.6144 - 9s/epoch - 60ms/step
# Epoch 11/100
# 150/150 - 9s - loss: 1.1688 - accuracy: 0.6602 - 9s/epoch - 60ms/step
# Epoch 12/100
# ...

# %%
MAX_LABEL = 54
model = DFNet_Leaky.build(input_shape=(10000, 1), classes=MAX_LABEL)
# 옵티마이저 설정 
OPTIMIZER = Adamax(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
train_loop(model, OPTIMIZER, MAX_LABEL, data, test_size=0.2, first_task = 39, inc_task = 10, first_epochs = 100, inc_epochs = 50, lamb=0.5, num_sample=100)
# Out:
# Epoch 1/100
# 200/200 - 15s - loss: 3.7466 - accuracy: 0.0833 - 15s/epoch - 76ms/step
# Epoch 2/100
# 200/200 - 12s - loss: 3.1800 - accuracy: 0.1616 - 12s/epoch - 60ms/step
# Epoch 3/100
# 200/200 - 12s - loss: 2.9243 - accuracy: 0.2108 - 12s/epoch - 61ms/step
# Epoch 4/100
# 200/200 - 13s - loss: 2.7032 - accuracy: 0.2630 - 13s/epoch - 63ms/step
# Epoch 5/100
# 200/200 - 13s - loss: 2.5153 - accuracy: 0.3088 - 13s/epoch - 63ms/step
# Epoch 6/100
# 200/200 - 13s - loss: 2.2920 - accuracy: 0.3548 - 13s/epoch - 63ms/step
# Epoch 7/100
# 200/200 - 13s - loss: 2.1423 - accuracy: 0.4016 - 13s/epoch - 64ms/step
# Epoch 8/100
# 200/200 - 13s - loss: 1.9836 - accuracy: 0.4472 - 13s/epoch - 63ms/step
# Epoch 9/100
# 200/200 - 13s - loss: 1.8537 - accuracy: 0.4798 - 13s/epoch - 64ms/step
# Epoch 10/100
# 200/200 - 13s - loss: 1.6753 - accuracy: 0.5400 - 13s/epoch - 66ms/step
# Epoch 11/100
# 200/200 - 13s - loss: 1.5375 - accuracy: 0.5730 - 13s/epoch - 63ms/step
# Epoch 12/100
# ...

# %%
MAX_LABEL = 94
model = DFNet_Leaky.build(input_shape=(10000, 1), classes=MAX_LABEL)
# 옵티마이저 설정 
OPTIMIZER = Adamax(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
train_loop(model, OPTIMIZER, MAX_LABEL, data, test_size=0.2, first_task = 69, inc_task = 5, first_epochs = 100, inc_epochs = 10, lamb=0.5, num_sample=100)
# Out:
# Epoch 1/100
# 350/350 - 25s - loss: 4.2898 - accuracy: 0.0559 - 25s/epoch - 70ms/step
# Epoch 2/100
# 350/350 - 21s - loss: 3.7435 - accuracy: 0.1072 - 21s/epoch - 61ms/step
# Epoch 3/100
# 350/350 - 22s - loss: 3.4296 - accuracy: 0.1569 - 22s/epoch - 64ms/step
# Epoch 4/100
# 350/350 - 22s - loss: 3.1708 - accuracy: 0.2084 - 22s/epoch - 63ms/step
# Epoch 5/100
# 350/350 - 21s - loss: 2.9050 - accuracy: 0.2619 - 21s/epoch - 61ms/step
# Epoch 6/100
# 350/350 - 21s - loss: 2.6890 - accuracy: 0.3057 - 21s/epoch - 61ms/step
# Epoch 7/100
# 350/350 - 21s - loss: 2.4913 - accuracy: 0.3602 - 21s/epoch - 61ms/step
# Epoch 8/100
# 350/350 - 22s - loss: 2.3299 - accuracy: 0.3996 - 22s/epoch - 62ms/step
# Epoch 9/100
# 350/350 - 23s - loss: 2.1649 - accuracy: 0.4496 - 23s/epoch - 65ms/step
# Epoch 10/100
# 350/350 - 21s - loss: 1.9981 - accuracy: 0.4870 - 21s/epoch - 61ms/step
# Epoch 11/100
# 350/350 - 21s - loss: 1.8377 - accuracy: 0.5245 - 21s/epoch - 61ms/step
# Epoch 12/100
# ...

# %%
MAX_LABEL = 94
model = DFNet_Leaky.build(input_shape=(10000, 1), classes=MAX_LABEL)
# 옵티마이저 설정 
OPTIMIZER = Adamax(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
train_loop(model, OPTIMIZER, MAX_LABEL, data, test_size=0.2, first_task = 69, inc_task = 5, first_epochs = 100, inc_epochs = 30, lamb=0.5, num_sample=100)
# Out:
# Epoch 1/100
# 350/350 - 24s - loss: 4.3023 - accuracy: 0.0550 - 24s/epoch - 70ms/step
# Epoch 2/100
# 350/350 - 22s - loss: 3.7730 - accuracy: 0.1052 - 22s/epoch - 62ms/step
# Epoch 3/100
# 350/350 - 23s - loss: 3.4448 - accuracy: 0.1512 - 23s/epoch - 64ms/step
# Epoch 4/100
# 350/350 - 21s - loss: 3.1646 - accuracy: 0.2096 - 21s/epoch - 61ms/step
# Epoch 5/100
# 350/350 - 21s - loss: 2.9055 - accuracy: 0.2657 - 21s/epoch - 61ms/step
# Epoch 6/100
# 350/350 - 21s - loss: 2.7030 - accuracy: 0.3114 - 21s/epoch - 61ms/step
# Epoch 7/100
# 350/350 - 21s - loss: 2.4886 - accuracy: 0.3627 - 21s/epoch - 61ms/step
# Epoch 8/100
# 350/350 - 23s - loss: 2.3313 - accuracy: 0.3995 - 23s/epoch - 64ms/step
# Epoch 9/100
# 350/350 - 22s - loss: 2.1532 - accuracy: 0.4476 - 22s/epoch - 64ms/step
# Epoch 10/100
# 350/350 - 21s - loss: 2.0041 - accuracy: 0.4934 - 21s/epoch - 61ms/step
# Epoch 11/100
# 350/350 - 21s - loss: 1.8523 - accuracy: 0.5240 - 21s/epoch - 61ms/step
# Epoch 12/100
# ...

# %%
MAX_LABEL = 94
model = DFNet_Leaky.build(input_shape=(10000, 1), classes=MAX_LABEL)
# 옵티마이저 설정 
OPTIMIZER = Adamax(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
train_loop(model, OPTIMIZER, MAX_LABEL, data, test_size=0.2, first_task = 69, inc_task = 5, first_epochs = 100, inc_epochs = 1, lamb=0.5, num_sample=100)

# %%
MAX_LABEL = 94
model = DFNet_Leaky.build(input_shape=(10000, 1), classes=MAX_LABEL)
# 옵티마이저 설정 
OPTIMIZER = Adamax(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
train_loop(model, OPTIMIZER, MAX_LABEL, data, test_size=0.2, first_task = 69, inc_task = 5, first_epochs = 100, inc_epochs = 50, lamb=0.5, num_sample=100)
# Out:
# Epoch 1/100
# 350/350 - 24s - loss: 4.2995 - accuracy: 0.0543 - 24s/epoch - 70ms/step
# Epoch 2/100
# 350/350 - 22s - loss: 3.7479 - accuracy: 0.1079 - 22s/epoch - 64ms/step
# Epoch 3/100
# 350/350 - 22s - loss: 3.4001 - accuracy: 0.1624 - 22s/epoch - 62ms/step
# Epoch 4/100
# 350/350 - 21s - loss: 3.1262 - accuracy: 0.2158 - 21s/epoch - 61ms/step
# Epoch 5/100
# 350/350 - 21s - loss: 2.8789 - accuracy: 0.2684 - 21s/epoch - 61ms/step
# Epoch 6/100
# 350/350 - 21s - loss: 2.6549 - accuracy: 0.3201 - 21s/epoch - 61ms/step
# Epoch 7/100
# 350/350 - 22s - loss: 2.4682 - accuracy: 0.3684 - 22s/epoch - 63ms/step
# Epoch 8/100
# 350/350 - 23s - loss: 2.2842 - accuracy: 0.4195 - 23s/epoch - 65ms/step
# Epoch 9/100
# 350/350 - 21s - loss: 2.1147 - accuracy: 0.4580 - 21s/epoch - 61ms/step
# Epoch 10/100
# 350/350 - 21s - loss: 1.9704 - accuracy: 0.5009 - 21s/epoch - 61ms/step
# Epoch 11/100
# 350/350 - 21s - loss: 1.8237 - accuracy: 0.5376 - 21s/epoch - 61ms/step
# Epoch 12/100
# ...

# %%
MAX_LABEL = 94
model = DFNet_Leaky.build(input_shape=(10000, 1), classes=MAX_LABEL)
# 옵티마이저 설정 
OPTIMIZER = Adamax(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
train_loop(model, OPTIMIZER, MAX_LABEL, data, test_size=0.2, first_task = 69, inc_task = 5, first_epochs = 100, inc_epochs = 30, lamb=100, num_sample=100)
# Out:
# Epoch 1/100
# 350/350 - 26s - loss: 4.2867 - accuracy: 0.0579 - 26s/epoch - 74ms/step
# Epoch 2/100
# 350/350 - 22s - loss: 3.7486 - accuracy: 0.1088 - 22s/epoch - 62ms/step
# Epoch 3/100
# 350/350 - 21s - loss: 3.4633 - accuracy: 0.1570 - 21s/epoch - 61ms/step
# Epoch 4/100
# 350/350 - 21s - loss: 3.1380 - accuracy: 0.2107 - 21s/epoch - 61ms/step
# Epoch 5/100
# 350/350 - 21s - loss: 2.8814 - accuracy: 0.2746 - 21s/epoch - 61ms/step
# Epoch 6/100
# 350/350 - 22s - loss: 2.6831 - accuracy: 0.3133 - 22s/epoch - 62ms/step
# Epoch 7/100
# 350/350 - 22s - loss: 2.4931 - accuracy: 0.3595 - 22s/epoch - 63ms/step
# Epoch 8/100
# 350/350 - 21s - loss: 2.3003 - accuracy: 0.4092 - 21s/epoch - 61ms/step
# Epoch 9/100
# 350/350 - 21s - loss: 2.1348 - accuracy: 0.4506 - 21s/epoch - 61ms/step
# Epoch 10/100
# 350/350 - 21s - loss: 1.9881 - accuracy: 0.4888 - 21s/epoch - 61ms/step
# Epoch 11/100
# 350/350 - 21s - loss: 1.8495 - accuracy: 0.5259 - 21s/epoch - 61ms/step
# Epoch 12/100
# ...

# %%
MAX_LABEL = 94
model = DFNet_Leaky.build(input_shape=(10000, 1), classes=MAX_LABEL)
# 옵티마이저 설정 
OPTIMIZER = Adamax(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
train_loop(model, OPTIMIZER, MAX_LABEL, data, test_size=0.2, first_task = 69, inc_task = 5, first_epochs = 100, inc_epochs = 50, lamb=100, num_sample=100)
# Out:
# Epoch 1/100
# 350/350 - 25s - loss: 4.3325 - accuracy: 0.0521 - 25s/epoch - 73ms/step
# Epoch 2/100
# 350/350 - 21s - loss: 3.7962 - accuracy: 0.0996 - 21s/epoch - 60ms/step
# Epoch 3/100
# 350/350 - 21s - loss: 3.4935 - accuracy: 0.1470 - 21s/epoch - 60ms/step
# Epoch 4/100
# 350/350 - 21s - loss: 3.1809 - accuracy: 0.2007 - 21s/epoch - 61ms/step
# Epoch 5/100
# 350/350 - 21s - loss: 2.9288 - accuracy: 0.2564 - 21s/epoch - 61ms/step
# Epoch 6/100
# 350/350 - 23s - loss: 2.6923 - accuracy: 0.3113 - 23s/epoch - 64ms/step
# Epoch 7/100
# 350/350 - 22s - loss: 2.5008 - accuracy: 0.3621 - 22s/epoch - 62ms/step
# Epoch 8/100
# 350/350 - 21s - loss: 2.3248 - accuracy: 0.4071 - 21s/epoch - 61ms/step
# Epoch 9/100
# 350/350 - 21s - loss: 2.1479 - accuracy: 0.4520 - 21s/epoch - 61ms/step
# Epoch 10/100
# 350/350 - 21s - loss: 1.9727 - accuracy: 0.4971 - 21s/epoch - 61ms/step
# Epoch 11/100
# 350/350 - 22s - loss: 1.8268 - accuracy: 0.5307 - 22s/epoch - 64ms/step
# Epoch 12/100
# ...
